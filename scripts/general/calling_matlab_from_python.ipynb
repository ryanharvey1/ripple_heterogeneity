# %%
import matlab.engine
import matplotlib.pyplot as plt
eng = matlab.engine.start_matlab()

# %%
x = [1,1,1,1,2,3,2,1,2,4,3,3,4,8,5,9,13,14,7,8,6,7,5,3,1,2,1,1,3,2,1,1,1]
x = matlab.double(x)
tf = eng.mean(x)
print(tf)
# Out:
# 3.4838709677419355

# %%
eng.addpath(r'D:\github\neurocode\PlaceCells',nargout=0)

# %%
# x = [1,1,1,1,2,3,2,1,2,4,3,3,4,8,5,9,13,14,7,8,6,7,5,3,1,2,1,1,3,2,1,1,1]
# x = matlab.double(x)
# stats = eng.MapStats(x)

# %%
x = [1,1,1,1,2,3,2,1,2,4,3,3,4,8,5,9,13,14,7,8,6,7,5,3,1,2,1,1,3,2,1,1,1]

plt.plot(x)
plt.show()
