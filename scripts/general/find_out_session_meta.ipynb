# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from ripple_heterogeneity.utils import loading
import pandas as pd

# %%
df = pd.read_csv(r"Z:\home\ryanh\projects\ripple_heterogeneity\sessions.csv")

region_df = pd.DataFrame()
for basepath in df.basepath:
    brainRegions = loading.load_brain_regions(basepath)
    temp_df = pd.DataFrame()
    temp_df["brainRegions"] = brainRegions.keys()
    temp_df["basepath"] = basepath
    region_df = pd.concat([region_df, temp_df], ignore_index=True)
region_df
# sessions = region_df[region_df.brainRegions.str.contains("PFC|EC1|EC2|EC3|EC4|EC5|MEC")]
# df_sessions = pd.DataFrame()
# df_sessions["basepath"] = sessions.basepath.unique()
# df_sessions
# Out:
#      brainRegions                         basepath
# 0          CA1slm          Z:\Data\AYAold\AB1\day1
# 1           CA1so          Z:\Data\AYAold\AB1\day1
# 2           CA1sp          Z:\Data\AYAold\AB1\day1
# 3           CA1sr          Z:\Data\AYAold\AB1\day1
# 4             CA3          Z:\Data\AYAold\AB1\day1
# ...           ...                              ...
# 1365        CA1so  Z:\Data\ORproject\OR15\hc300118
# 1366        CA1sp  Z:\Data\ORproject\OR15\hc300118
# 1367        CA1sr  Z:\Data\ORproject\OR15\hc300118
# 1368          CTX  Z:\Data\ORproject\OR15\hc300118
# 1369        DGCA3  Z:\Data\ORproject\OR15\hc300118
#
# [1370 rows x 2 columns]

# %% [markdown]
# ### brainRegions
#
# according to allen institute
#
# ex.
#
# CA1so,CA1sp,CA1sr,CA1slm,etc.

# %%
region_df.brainRegions.value_counts()

# %% [markdown]
# ## Epochs
#
# name: name of subfolder
#
# startTime: start time of epoch
#
# stopTime: end time of epoch
#
# environment: environment of epoch ('sleep', 'linear', 'tmaze', 'cheeseboard', 'box','unknown','wheel', 'plus', 'ZigZag', 'wmaze' )
#
# notes: notes about epoch
#
# manipulation: note about what manipulation was done ('mec_silencing','pfc_silencing','ripple_prolong','ripple_silence')

# %%
# loading.load_epoch(basepath)

epoch_df = pd.DataFrame()
for basepath in df.basepath:
    epochs = loading.load_epoch(basepath)
    epoch_df = pd.concat([epoch_df, epochs], ignore_index=True)

epoch_df
# Out:
#                                       name   startTime     stopTime  \
# 0                                      pre      0.0000   1139.99920
# 1                                     task   1140.0008   4199.99920
# 2                                    sleep      0.0000   2520.00000
# 3                                    tmaze   2520.0000   3600.00000
# 4                                   sleep2   3600.0000   6240.00000
# ...                                    ...         ...          ...
# 2150  rec4_sleep_after_delay_180128_163333  15336.8320  22395.03995
# 2151              1_sleep_CL_180130_125729      0.0000      0.00000
# 2152              2_sleep_CL_180130_131145      0.0000   7231.90400
# 2153           3_sleep_delay_180130_151350   7231.9040  14575.07200
# 2154             4_sleep_CL2_180130_171917  14575.0720  21522.52800
#
#      environment behavioralParadigm notes behavioralParadigmID  \
# 0          sleep                  1   NaN                  NaN
# 1         linear                  1   NaN                  NaN
# 2          sleep                  1   NaN                  NaN
# 3          tmaze                  1   NaN                  NaN
# 4          sleep                  1   NaN                  NaN
# ...          ...                ...   ...                  ...
# 2150       sleep                NaN   NaN                  NaN
# 2151       sleep                NaN   NaN                  NaN
# 2152       sleep                NaN   NaN                  NaN
# 2153       sleep                NaN   NaN                  NaN
# 2154       sleep                NaN   NaN                  NaN
#
#      environmentType environmentID manipulation manipulationID  entryID
# 0                NaN           NaN          NaN            NaN      NaN
# 1                NaN           NaN          NaN            NaN      NaN
# 2                NaN           NaN          NaN            NaN      NaN
# 3                NaN           NaN          NaN            NaN      NaN
# 4                NaN           NaN          NaN            NaN      NaN
# ...              ...           ...          ...            ...      ...
# 2150             NaN           NaN          NaN            NaN      NaN
# 2151             NaN           NaN          NaN            NaN      NaN
# 2152             NaN           NaN          NaN            NaN      NaN
# 2153             NaN           NaN          NaN            NaN      NaN
# 2154             NaN           NaN          NaN            NaN      NaN
#
# [2155 rows x 12 columns]

# %%
epoch_df.manipulation.unique()
# Out:
# array([nan, '', 'opto', 'mec_silencing', 'opto_inbound', 'opto_outbound'],
#       dtype=object)
